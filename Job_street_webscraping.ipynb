# %%
import urllib
import requests
import json
import pandas as pd

# %%
url = "https://www.jobstreet.com.my/en/companies/442827-kumpulan-wang-simpanan-pekerja-kwsp/reviews"
data = urllib.request.urlopen(url).read()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-3-a1e2854cf3d5> in <module>
#       1 url = "https://www.jobstreet.com.my/en/companies/442827-kumpulan-wang-simpanan-pekerja-kwsp/reviews"
# ----> 2 data = urllib.request.urlopen(url).read()
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ...

# %%
from bs4 import BeautifulSoup
import requests 
from urllib.request import urlopen
from selenium.webdriver import ActionChains
from selenium import webdriver
import pandas as pd

# %%
options = webdriver.ChromeOptions()
#path = "http://www.indeed.com"
#Comp = "https://www.indeed.com/cmp/L'or%C3%A9al-1/reviews"
driver = webdriver.Chrome(r'C:\Users\prerana.a.singh\Downloads\chromedriver_win32 (1)\chromedriver.exe',options=options)

# %%
driver.get("https://www.jobstreet.com.my/en/companies/442827-kumpulan-wang-simpanan-pekerja-kwsp/reviews?page=2")

# %%
content = driver.page_source

# %%
soup = BeautifulSoup(content)

# %%
soup
# Out:
# <html lang="en"><head prefix="og: http://ogp.me/ns#">
# <link data-chunk="main" href="https://cpp-prod-js-web-assets.s3.amazonaws.com/152/vendors~main.css.gz" rel="stylesheet"/>
# <link data-chunk="main" href="https://cpp-prod-js-web-assets.s3.amazonaws.com/152/vendors~main-822546f9a6a3c1cf479a.css.gz" rel="stylesheet"/>
# <link data-chunk="main" href="https://cpp-prod-js-web-assets.s3.amazonaws.com/152/main.css.gz" rel="stylesheet"/>
# <link data-chunk="main" href="https://cpp-prod-js-web-assets.s3.amazonaws.com/152/main-d9cbbb0d5f3f33a0404d.css.gz" rel="stylesheet"/>
# <link as="script" crossorigin="anonymous" data-chunk="main" href="https://cpp-prod-js-web-assets.s3.amazonaws.com/152/runtime-78389f769be1ccf1bab2.js.gz" rel="preload"/>
# <link as="script" crossorigin="anonymous" data-chunk="main" href="https://cpp-prod-js-web-assets.s3.amazonaws.com/152/vendors~main-7cad4da8f64b0fcad593.js.gz" rel="preload"/>
# ...

# %%
Title = soup.findAll('h3', {'class':'_3MyALCcnLdxQbK6kunFzgk'})

# %%
Title
# Out:
# [<h3 class="_3MyALCcnLdxQbK6kunFzgk"><a href="/en/companies/442827-kumpulan-wang-simpanan-pekerja-kwsp/reviews/160077163444840">My working experience is a cashier</a></h3>,
#  <h3 class="_3MyALCcnLdxQbK6kunFzgk"><a href="/en/companies/442827-kumpulan-wang-simpanan-pekerja-kwsp/reviews/160023157412215">Enjoying with the work life</a></h3>,
#  <h3 class="_3MyALCcnLdxQbK6kunFzgk"><a href="/en/companies/442827-kumpulan-wang-simpanan-pekerja-kwsp/reviews/160006172575101">Manage the company flow</a></h3>,
#  <h3 class="_3MyALCcnLdxQbK6kunFzgk"><a href="/en/companies/442827-kumpulan-wang-simpanan-pekerja-kwsp/reviews/159995025016380">good management doin the work together</a></h3>,
#  <h3 class="_3MyALCcnLdxQbK6kunFzgk"><a href="/en/companies/442827-kumpulan-wang-simpanan-pekerja-kwsp/reviews/159992745044802">I not have any experience</a></h3>,
# ...

# %%
#soup.find('a', {'class':"a37 ga_tracking"})['href']

# %%
review2 = soup.find('h3', {'class':'_3MyALCcnLdxQbK6kunFzgk'}).text

# %%
review2
# Out:
# 'My working experience is a cashier'

# %%
Good_Things = soup.findAll('div', {'id':'good-review'})

# %%
Good_Things
# Out:
# [<div class="_2NfE_Vr9YcvPmkQKmZVNL0" id="good-review"><div class="_3oDy3INXM4D5NEhRbMgqjy" style="height: auto;"><div>I like this working because this working have a new life for me. And then, I want to become succesful in my life</div></div></div>,
#  <div class="_2NfE_Vr9YcvPmkQKmZVNL0" id="good-review"><div class="_3oDy3INXM4D5NEhRbMgqjy" style="height: auto;"><div>Environment friendly and easier to make friends</div></div></div>,
#  <div class="_2NfE_Vr9YcvPmkQKmZVNL0" id="good-review"><div class="_3oDy3INXM4D5NEhRbMgqjy" style="height: auto;"><div>Get a good environment engangement with people</div></div></div>,
#  <div class="_2NfE_Vr9YcvPmkQKmZVNL0" id="good-review"><div class="_3oDy3INXM4D5NEhRbMgqjy" style="height: auto;"><div>good doing work in one group.challenge  me to doing work from other side my study .hope their are my lucky in this job hopefully</div></div></div>,
# ...

# %%
Challenge_review = soup.findAll('div', {'id':'challange-review'})

# %%
Challenge_review
# Out:
# [<div class="_2NfE_Vr9YcvPmkQKmZVNL0" id="challange-review"><div class="_3oDy3INXM4D5NEhRbMgqjy" style="height: auto;"><div>I'm so enjoyful when I'm got to the interview. And then, i am get ready to working when I want to work here</div></div></div>,
#  <div class="_2NfE_Vr9YcvPmkQKmZVNL0" id="challange-review"><div class="_3oDy3INXM4D5NEhRbMgqjy" style="height: auto;"><div>Working with different types of customer that need to be more patient</div></div></div>,
#  <div class="_2NfE_Vr9YcvPmkQKmZVNL0" id="challange-review"><div class="_3oDy3INXM4D5NEhRbMgqjy" style="height: auto;"><div>May give me a better performance in managing</div></div></div>,
#  <div class="_2NfE_Vr9YcvPmkQKmZVNL0" id="challange-review"><div class="_3oDy3INXM4D5NEhRbMgqjy" style="height: auto;"><div>other side from my study</div></div></div>,
#  <div class="_2NfE_Vr9YcvPmkQKmZVNL0" id="challange-review"><div class="_3oDy3INXM4D5NEhRbMgqjy" style="height: auto;"><div>Enjoy work
#  Proud
#  Good work
# ...

# %%
Profession = soup.findAll('p', {'class':'_1xPYIUfA9IwtVyBsOt_SaR'})

# %%
Profession
# Out:
# [<p class="_1xPYIUfA9IwtVyBsOt_SaR">Assistant</p>,
#  <p class="_1xPYIUfA9IwtVyBsOt_SaR">Customer services</p>,
#  <p class="_1xPYIUfA9IwtVyBsOt_SaR">Pegawai pemasaran</p>,
#  <p class="_1xPYIUfA9IwtVyBsOt_SaR">ok</p>,
#  <p class="_1xPYIUfA9IwtVyBsOt_SaR">Secretary</p>,
#  <p class="_1xPYIUfA9IwtVyBsOt_SaR">Business analyst manager</p>,
#  <p class="_1xPYIUfA9IwtVyBsOt_SaR">Admin</p>,
#  <p class="_1xPYIUfA9IwtVyBsOt_SaR">Kumpulan Wang Simpanan Pekerja (KWSP)</p>,
#  <p class="_1xPYIUfA9IwtVyBsOt_SaR">Forecourt cashier</p>,
#  <p class="_1xPYIUfA9IwtVyBsOt_SaR">Customer service officer</p>]

# %%
Month = soup.findAll('p', {'class':'_1_dikBfyioZMrCoMA4C9hZ'})

# %%
Month
# Out:
# [<p class="_1_dikBfyioZMrCoMA4C9hZ"><span>Sep 2020</span></p>,
#  <p class="_1_dikBfyioZMrCoMA4C9hZ"><span>Sep 2020</span></p>,
#  <p class="_1_dikBfyioZMrCoMA4C9hZ"><span>Sep 2020</span></p>,
#  <p class="_1_dikBfyioZMrCoMA4C9hZ"><span>Sep 2020</span></p>,
#  <p class="_1_dikBfyioZMrCoMA4C9hZ"><span>Sep 2020</span></p>,
#  <p class="_1_dikBfyioZMrCoMA4C9hZ"><span>Sep 2020</span></p>,
#  <p class="_1_dikBfyioZMrCoMA4C9hZ"><span>Sep 2020</span></p>,
#  <p class="_1_dikBfyioZMrCoMA4C9hZ"><span>Sep 2020</span></p>,
#  <p class="_1_dikBfyioZMrCoMA4C9hZ"><span>Sep 2020</span></p>,
#  <p class="_1_dikBfyioZMrCoMA4C9hZ"><span>Sep 2020</span></p>]

# %%
work_location = soup.findAll('div', {'id':'work-location'})

# %%
work_location
# Out:
# [<div id="work-location">Jalan Raja Chulan</div>,
#  <div id="work-location">Negeri Sembilan, Malaysia</div>,
#  <div id="work-location">Kulim, Kedah, Malaysia</div>,
#  <div id="work-location">Kuala Lumpur International Airport, Sepang, Selangor, Malaysia</div>]

# %%
work_year = soup.findAll('div', {'id':'years-worked-with'})

# %%
work_year
# Out:
# [<div id="years-worked-with"><span><span>Less than 1 year in the role</span>,<!-- --> </span></div>,
#  <div id="years-worked-with"><span><span>Less than 1 year in the role</span>,<!-- --> </span><span><span>former employee</span></span></div>,
#  <div id="years-worked-with"><span><span>More than 12 years in the role</span>,<!-- --> </span><span><span>former employee</span></span></div>]

# %%
Rating = soup.findAll('span', {'class':'Tlh9F04dzRFo78gJPlhMM'})

# %%
Rating
# Out:
# [<span class="Tlh9F04dzRFo78gJPlhMM">3.0</span>,
#  <span class="Tlh9F04dzRFo78gJPlhMM">5.0</span>,
#  <span class="Tlh9F04dzRFo78gJPlhMM">5.0</span>,
#  <span class="Tlh9F04dzRFo78gJPlhMM">3.0</span>,
#  <span class="Tlh9F04dzRFo78gJPlhMM">1.0</span>,
#  <span class="Tlh9F04dzRFo78gJPlhMM">5.0</span>,
#  <span class="Tlh9F04dzRFo78gJPlhMM">3.0</span>,
#  <span class="Tlh9F04dzRFo78gJPlhMM">5.0</span>,
#  <span class="Tlh9F04dzRFo78gJPlhMM">5.0</span>,
#  <span class="Tlh9F04dzRFo78gJPlhMM">5.0</span>]

# %%
####Complete Code



##complete
from bs4 import BeautifulSoup
import requests 
from urllib.request import urlopen
from selenium.webdriver import ActionChains
from selenium import webdriver
import pandas as pd

from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
from scrapy.http import HtmlResponse
from selenium import webdriver
import pandas as pd
import time
from datetime import date, timedelta, datetime
from selenium.common.exceptions import NoSuchElementException
options = webdriver.ChromeOptions()


from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
from selenium.webdriver import ActionChains


driver = webdriver.Chrome(r'C:\Users\prerana.a.singh\Downloads\chromedriver_win32 (1)\chromedriver.exe',options=options)

import time
time.sleep(10)


for i in range(0, 4, 1):
    print(i)
    driver.get("https://www.jobstreet.com.sg/en/companies/660578-singapore-press-holdings-ltd/reviews?page="+str(i))
    
    #url = urlopen("https://www.graduateprograms.com/schools/tufts-university?page=10")
    #url = urlopen("https://www.yelp.com/biz/tufts-university-medford-somerville-campus-medford-5")
    #print(url.read())
    time.sleep(10)
    
    
    
    content = driver.page_source
    soup = BeautifulSoup(content)
    #print(soup)
    
    
    
    
    Title = soup.findAll('h3', {'class':'_3MyALCcnLdxQbK6kunFzgk'})#reviews1
    
    Good_Things = soup.findAll('div', {'id':'good-review'})

    
    Challenge_review = soup.findAll('div', {'id':'challange-review'})
    
    Profession = soup.findAll('p', {'class':'_1xPYIUfA9IwtVyBsOt_SaR'})
    
    Month = soup.findAll('p', {'class':'_1_dikBfyioZMrCoMA4C9hZ'})
    
    work_location = soup.findAll('div', {'id':'work-location'})
    
    work_year = soup.findAll('div', {'id':'years-worked-with'})
    
    Rating = soup.findAll('span', {'class':'Tlh9F04dzRFo78gJPlhMM'})
    
    
    
    
    df = pd.DataFrame(list(zip(Title,Good_Things,Challenge_review,Profession,Month,work_location,work_year,Rating)))
    
    df.to_excel(r'C:\Users\prerana.a.singh\OneDrive - Accenture\PVP\Companies\Singapore Press Holdings'+str(i)+'_yelpreviews_complete0'+'.xlsx')
# Out:
# 0
# 1
# 2
# 3

# %%
from glob import glob
file_list = glob(r'C:\Users\prerana.a.singh\OneDrive - Accenture\PVP\Companies'  + '*.xlsx')
df_list = [pd.read_excel(file) for file in file_list]
complete_df = pd.concat(df_list, axis=0)
complete_df.to_excel(path + '/Data/'  + 'Job_street_complete.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-5f55381cf5c7> in <module>
#       2 file_list = glob(r'C:\Users\prerana.a.singh\OneDrive - Accenture\PVP\Companies'  + '*.xlsx')
#       3 df_list = [pd.read_excel(file) for file in file_list]
# ----> 4 complete_df = pd.concat(df_list, axis=0)
#       5 complete_df.to_excel(path + '/Data/'  + 'Job_street_complete.xlsx', index=False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     253         verify_integrity=verify_integrity,
#     254         copy=copy,
# --> 255         sort=sort,
#     256     )
#     257
#
# ...
